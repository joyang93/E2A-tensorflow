# %%
import pickle

# %%
with open("part3.txt", "rb") as f:
    df = pickle.load(f)
f.close()

# %%
df.head()
# Out:
#   article_title                                       article_cont  \
# 0           NaN  문재인 대통령이 일 자신의 를 통해 반려견인 토리 마루와의 일상을 전했다   문재인...
# 1           NaN  문재인 대통령이 일 오후 세종시 정부세종컨벤션센터에서 열린  기획재정부 공정거래위원...
# 2           NaN  배훈식   일 오후 서울 여의도 국회 법제사법위원회에 참석한 박상기 법무부 장관이 ...
# 3           NaN  여야 의원들 참여한 포럼 발족정부 포용적 금융 핵심 과제로유병자 보험 추진 착한기업...
# 4           NaN  사진연합 사진연합주말 잠시 휴식기에 돌입한 문재인 정부 첫 정부부처 업무보고가 후반...
#
#                                        summarization  sum_type
# 0  문재인 대통령이 일 자신의 를 통해 반려견인 토리 마루와의 일상을 전했다 문 대통령...   lexrank
# 1   문 대통령은 일 국방부와 국가보훈처를 한 자리에서 다시 행정안전부 법부무 국민권익...   lexrank
# 2   전신   문재인 대통령이 일 청와대 본관에서 박상기 법무부 장관에게 임명장을 수여...  textrank
# 3  여야 의원들 참여한 포럼 발족정부 포용적 금융 핵심 과제로유병자 보험 추진 착한기업...  textrank
# 4   특히 부동산 정책을 총괄하는 국토교통부 업무보고엔 국민적 관심이 집중될 전망이다 ...   lexrank

# %%
df.summarization
# Out:
# 0        문재인 대통령이 일 자신의 를 통해 반려견인 토리 마루와의 일상을 전했다 문 대통령...
# 1         문 대통령은 일 국방부와 국가보훈처를 한 자리에서 다시 행정안전부 법부무 국민권익...
# 2         전신   문재인 대통령이 일 청와대 본관에서 박상기 법무부 장관에게 임명장을 수여...
# 3        여야 의원들 참여한 포럼 발족정부 포용적 금융 핵심 과제로유병자 보험 추진 착한기업...
# 4         특히 부동산 정책을 총괄하는 국토교통부 업무보고엔 국민적 관심이 집중될 전망이다 ...
# 5        대통령 시계의 출납은 청와대의 살림살이를 도맡은 이정도 총무비서관이 사실상 결정권을...
# 6        사진박용진 의원  사진박용진 의원 사진전재수 의원  사진전재수 의원 더불어민주당 박...
# 7        청와대통상일정총리실통상일정국방부통상일정외교부통상일정통일부통상일정더불어민주당 취임 주...
# 8        서성일  문재인 대통령이 일 서울 도렴동 외교부 청사에서 열린 국방부국가보훈처 핵심...
# 9        국방부는 국방부국가보훈처 합동 업무보고인 핵심정책토의에서 방위사업 비리척결 및 국방...
# 10       국민권익위원회는 일 범국가 차원의 부패방지 시스템을 구축하기 위해 반부패청렴정책의 ...
# 11       김부겸 행정안전부 장관은 일 첫 대통령 업무보고에서 연방제 수준의 자치분권 국가를 ...
# 12       청와대가 지난달 심 재판에서 문화계 블랙리스트 사건과 관련해 무죄를 받은 조윤선 전...
# 13       문재인 대통령이 일 오후 서울 도렴동 정부 외교부 청사에서 열린 국방부 및 보훈처 ...
# 14       청와대 한 관계자는 대통령기록물인지 논쟁의 여지가 있는데 내용을 모두 공개할 경우 ...
# 15       문 대통령은 이날 오후 정부서울청사에서 가진 법무부 업무보고에서 검찰이 국민으로부터...
# 16       청와대 제공박근혜 정부 시절 문고리 인방 중 한 명인 안봉근 전 비서관이 이끌었던 ...
# 17       청와대가 오늘 추가로 발견했다고 발표한 문서 파일은 박근혜 정부 초기인 년부터 년 ...
# 18       청와대 박수현 대변인이 일 오후 청와대 브리핑룸에서 청와대 제부속실 등의 전 정부 ...
# 19       전진환   일 오후 청와대에서 열린 장차관 임명장 수여식에서 임명장을 받은 박은정 ...
# 20       이어 현재 진행 중인 이명박 정부 시절 국가정보원의 민간인 동원 사이버 여론조작 의...
# 21        이광호   문재인 대통령이 일 오후 서울 종로구 외교부 청사에서 열린  행정안전부...
# 22        이광호   문재인 대통령이 일 오후 서울 종로구 외교부 청사에서 열린  행정안전부...
# 23        이광호   문재인 대통령이 일 오후 서울 종로구 외교부 청사에서 열린  행정안전부...
# 24        이광호   문재인 대통령이 일 오후 서울 종로구 외교부 청사에서 열린  행정안전부...
# 25          서미선   청와대가 일 공식 소셜네트워크서비스를 통해 소박한 조국 민정수석실 ...
# 26       행안부 등 핵심정책토의 주재중앙이 먼저 권한 내려놔야국민안전은 국가 존재이유재난안전...
# 27       文 대통령 한미에 대해선 가장 고도화 양국 발전에 크게 기여문재인 대통령이 일 오전...
# 28        박진희   북한의 괌 포위사격 위협 성명이 나온 일 오후 정의용 국가안보실장 주재...
# 29       문재인 대통령이 일 오후 서울 도렴동 외교부 청사에서 열린  국방부국가보훈처 업무보...
#                                ...
# 31655                                                  NaN
# 31656                                                  NaN
# 31657                                                  NaN
# 31658                                                  NaN
# 31659                                                  NaN
# 31660                                                  NaN
# 31661                                                  NaN
# 31662                                                  NaN
# 31663                                                  NaN
# 31664                                                  NaN
# 31665                                                  NaN
# 31666                                                  NaN
# 31667                                                  NaN
# 31668                                                  NaN
# 31669                                                  NaN
# 31670                                                  NaN
# 31671                                                  NaN
# 31672                                                  NaN
# 31673                                                  NaN
# 31674                                                  NaN
# 31675                                                  NaN
# 31676                                                  NaN
# 31677                                                  NaN
# 31678                                                  NaN
# 31679                                                  NaN
# 31680                                                  NaN
# 31681                                                  NaN
# 31682                                                  NaN
# 31683                                                  NaN
# 31684                                                  NaN
# Name: summarization, Length: 23370, dtype: object

# %%
def remove_stopwords(stopwords, summarizations, col_name):
    total = []
    for summarization in summarizations:
        summarization = summarization.split()
        summarization = [t for t in summarization if len(t)>0]
        for i in range(len(summarization)):
            for stopword in stopwords:
                if summarization[i][-len(stopword):] == stopword:
                    summarization[i] = summarization[i].replace(stopword, "")
        
        summarization_sen = " ".join(summarization)
        total.append(summarization_sen)
    
    total = pd.DataFrame(total, columns=[col_name])
    
    return total

# %%
a = '안녕하세요'

# %%
len(a)
# Out:
# 5

# %%
stopwords = ["은","는", "이", "가", "을", "를", "에", "할", "과", "의", "도", "였", "았",
"됐","및", "수", "때", "것", "곧", "던", "또", "약", "된", "로", "씩", "듯","것", "씨", "었",
"될","와", "잘", "진", "중", "데", "게", "점", "시", "간","었","엔","만","께","들","등","다",


"다만", "보다", "직해", "지만", "라는", "위해", "라고", "으로", "다고", "했다", "였다",
"하고", "해야", "다며", "에서", "등에", "하며", "에는", "된다", "인데", "따라", "이에",
"정도", "라며", "치고", "이나", "에도", "데다", "려면", "것을", "것이", "등을", "특히",
"뿐만", "하면", "했던", "따른", "것도", "하는", "처럼", "리고", "이지", "면서", "대한",
"있어", "하게", "됐을", "까지", "로는", "되지", "하자", "있기", "만한", "됨에", "이란",
"나설", "등이", "았고", "부터", "해서", "에는", "되어", "이고", "에서", "이다", "에선", "니다",
"하며", "으며", "었다", "하려", "등을", "등은", "이자", "거나", "하지", "으론", "하기", "으니",
"에게", "로서", "로써", "돼야", "에겐", "됐다", "한테", "이면", "들께", "되자", "조차", "하라",
"이든", "했고", "보단", "되는", "들께", "이런", "당한", "드릴", "라든", "했다", "겠다", "다면",


"한다면", "으려면", "보인다", "보다는", "하다고", "에서만", "따르면", "이라는", "으로도", "합니다",
"당분간", "있다고", "스러운", "있을지", "것이란", "것으로", "중이다", "한다고", "아울러", "헸더니",
"시키는", "하면서", "이라고", "이라며", "이른바", "오히려", "된다고", "있음을", "등으로", "이예요",
"하고자", "에서도", "했다고", "에게서", "까지만", "되어야", "됐으며", "이었다", "이지만", "습니까",
"었지만", "했으며", "이겠냐", "으로서", "으로써", "됐거나", "됐으면", "했으나", "로부터", 
"에서는", "했으니", "에게는", "에게만", "으로나", "되거나", "하거나", "했어야", "이라도",
"한다는", "되었다", "이었던" ,"들에게", "이라면", "라거나", "라든지", "이면서", "이었다",
"했으면", "에서만", "되었다", "되었고", "됐다고", "하므로", "했는지", "해주길", "부터라",
"하면서", "해줘야", "으로는", "보다는", "해봐야", "되더라", "하더라", "으로선", "하다는",
                

"하겠다고", "만으로도", "이라면서", "보고서는", "것이라고", "시키거나", "보인다고","으로부터","했습니다",
"되었지만", "이겠냐만", "한다더니", "이야말로", "으로서는", "으로써는", "이어서가","되었거나", "하십니까",
"이었다면", "되었으며", "이었으니", "이었으나", "이었지만", "했으면서", "했다면서","하는구나",
"부터라서", "하면서는", "해봐야지", "해보아야", "되더라도", "하더라도", "하겠으나", "되었으나",

"하느냐인데","으로부터는"
]
